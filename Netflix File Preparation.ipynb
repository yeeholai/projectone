# %%
# good question and answer
# how can this analysis help make a business decision, give context for what they can do with that information
# put the holes in data in the presentation
# look for data first to inform the project

import warnings
warnings.filterwarnings("ignore")
import pandas as pd

# %%
happiness_index = pd.read_csv('Resources/happiness_index_2021.csv')
original_netflix = pd.read_csv("Resources/netflix full.csv")

# %%
original_netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9425 entries, 0 to 9424
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  9425 non-null   object
#  1   Genre                  9400 non-null   object
#  2   Tags                   9389 non-null   object
#  3   Languages              9266 non-null   object
#  4   Series or Movie        9425 non-null   object
#  5   Hidden Gem Score       9415 non-null   float64
#  6   Country Availability   9414 non-null   object
#  7   Runtime                9424 non-null   object
#  8   View Rating            6827 non-null   object
#  9   IMDb Score             9417 non-null   float64
#  10  Rotten Tomatoes Score  5445 non-null   float64
#  11  Metacritic Score       4082 non-null   float64
#  12  Awards Received        5226 non-null   float64
#  13  Awards Nominated For   6376 non-null   float64
#  14  Boxoffice              3754 non-null   object
#  15  Release Date           9217 non-null   object
#  16  Netflix Release Date   9425 non-null   object
#  17  IMDb Votes             9415 non-null   float64
#  18  Unnamed: 18            0 non-null      float64
#  19  Unnamed: 19            0 non-null      float64
# dtypes: float64(9), object(11)
# memory usage: 1.4+ MB

# %%
# Data Quality Check
# Comparing number of countries and languages a title is available.  Number of countries & languages expect to be reasonably close
# original_netflix[['Title','Languages','Country Availability']]

# # counting number of languages and countries in respective cell
# num_Language_per_title_test = original_netflix['Languages'].str.count(',')+1
# num_countries_per_title_test = original_netflix['Country Availability'].str.count(',')+1

# # setting those counts to append to the dataframe
# country_language_df = original_netflix
# country_language_df["# Countries"] = num_countries_per_title_test
# country_language_df["# Languages"] = num_Language_per_title_test
# country_language_df[['Title','Languages','Country Availability',"# Languages",'# Countries']]

# export results to csv for analysis
# country_language_df.to_csv(r"C:\Users\christina\Desktop\titles_count_languages.csv")

# %%
# Filling in blank values
# where Languages is blank, enter English
# where country availability is blank, enter United States

# 159 titles do not have languages associated with it

# Where languages are available, the list may not be complete. Example: Mind Explained is available in 36 countries, but
# is listed as only available in English. Checked on Netflix: title available in Portuguese, Spanish & French, Chinese subtitles
# in the US.

cleaned_df = original_netflix[['Title', 'Genre', 'Languages','Tags', 'Series or Movie',
       'Hidden Gem Score', 'Country Availability', 'Runtime', 'View Rating',
       'IMDb Score', 'Rotten Tomatoes Score', 'Metacritic Score',
       'Awards Received', 'Awards Nominated For', 'Boxoffice', 'Release Date',
       'Netflix Release Date', 'IMDb Votes']]
cleaned_df['Country Availability'].fillna('United States', inplace=True)
cleaned_df['Languages'].fillna('English', inplace=True)
cleaned_df[['Title','Languages','Country Availability']].info()
cleaned_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9425 entries, 0 to 9424
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Title                 9425 non-null   object
#  1   Languages             9425 non-null   object
#  2   Country Availability  9425 non-null   object
# dtypes: object(3)
# memory usage: 221.0+ KB
#                                           Title  \
# 0                              Lets Fight Ghost
# 1                           HOW TO BUILD A GIRL
# 2                              The Con-Heartist
# 3                                  Gleboka woda
# 4                                 Only a Mother
# ...                                         ...
# 9420                             13 Going on 30
# 9421                                   LIFE 2.0
# 9422                              Brand New Day
# 9423                Daniel Arends: Blessuretijd
# 9424  DreamWorks Happy Holidays from Madagascar
#
#                                        Genre            Languages  \
# 0     Crime, Drama, Fantasy, Horror, Romance     Swedish, Spanish
# 1                                     Comedy              English
# 2                            Comedy, Romance                 Thai
# 3                                      Drama               Polish
# 4                                      Drama              Swedish
# ...                                      ...                  ...
# 9420                Comedy, Fantasy, Romance  English, Portuguese
# 9421                             Documentary              English
# 9422                      Documentary, Music              English
# 9423                                  Comedy                Dutch
# 9424               Animation, Comedy, Family              English
#
#                                                    Tags Series or Movie  \
# 0     Comedy Programmes,Romantic TV Comedies,Horror ...          Series
# 1          Dramas,Comedies,Films Based on Books,British           Movie
# 2     Romantic Comedies,Comedies,Romantic Films,Thai...           Movie
# 3      TV Dramas,Polish TV Shows,Social Issue TV Dramas          Series
# 4     Social Issue Dramas,Dramas,Movies Based on Boo...           Movie
# ...                                                 ...             ...
# 9420  Romantic Comedies,Comedies,Romantic Films,Roma...           Movie
# 9421  Social & Cultural Documentaries,Biographical D...           Movie
# 9422  Australian Comedies,Romantic Comedies,Australi...           Movie
# 9423      Stand-up Comedy,International Movies,Comedies           Movie
# 9424  TV Comedies,Kids TV,Animal Tales,TV Cartoons,T...          Series
#
#       Hidden Gem Score                               Country Availability  \
# 0                  4.3                                           Thailand
# 1                  7.0                                             Canada
# 2                  8.6                                           Thailand
# 3                  8.7                                             Poland
# 4                  8.3  Lithuania,Poland,France,Italy,Spain,Greece,Bel...
# ...                ...                                                ...
# 9420               3.1  Hungary,Lithuania,Romania,United Kingdom,Belgi...
# 9421               8.2  Hungary,Lithuania,India,Australia,United Kingd...
# 9422               8.6                                          Australia
# 9423               8.8                                            Belgium
# 9424               8.4  Belgium,Switzerland,United States,Germany,Unit...
#
#            Runtime View Rating  IMDb Score  Rotten Tomatoes Score  \
# 0     < 30 minutes           R         7.9                   98.0
# 1         1-2 hour           R         5.8                   79.0
# 2          > 2 hrs         NaN         7.4                    NaN
# 3     < 30 minutes         NaN         7.5                    NaN
# 4         1-2 hour         NaN         6.7                    NaN
# ...            ...         ...         ...                    ...
# 9420      1-2 hour       PG-13         6.2                   65.0
# 9421      1-2 hour   Not Rated         6.2                   89.0
# 9422      1-2 hour         NaN         7.3                    NaN
# 9423      1-2 hour         NaN         7.8                    NaN
# 9424  < 30 minutes         NaN         6.8                    NaN
#
#       Metacritic Score  Awards Received  Awards Nominated For    Boxoffice  \
# 0                 82.0             74.0                  57.0   $2,122,065
# 1                 69.0              1.0                   NaN      $70,632
# 2                  NaN              NaN                   NaN          NaN
# 3                  NaN              2.0                   4.0          NaN
# 4                  NaN              2.0                   1.0          NaN
# ...                ...              ...                   ...          ...
# 9420              57.0              NaN                  11.0  $57,231,747
# 9421              65.0              1.0                   NaN          NaN
# 9422               NaN              NaN                   NaN          NaN
# 9423               NaN              NaN                   NaN          NaN
# 9424               NaN              NaN                   NaN          NaN
#
#      Release Date Netflix Release Date  IMDb Votes
# 0     12 Dec 2008           2021-03-04    205926.0
# 1     08 May 2020           2021-03-04      2838.0
# 2     03 Dec 2020           2021-03-03       131.0
# 3     14 Jun 2011           2021-03-03        47.0
# 4     31 Oct 1949           2021-03-03        88.0
# ...           ...                  ...         ...
# 9420  23 Apr 2004           2015-04-14    167842.0
# 9421  22 Jan 2010           2015-04-14       878.0
# 9422  17 Sep 1988           2015-04-14        14.0
# 9423  13 Jan 2012           2015-04-14       174.0
# 9424          NaN           2015-04-14        71.0
#
# [9425 rows x 18 columns]

# %%
# code to separate Country Availability into invidual rows
explode_Country = cleaned_df[['Title', 'Genre', 'Tags', 'Languages', 'Series or Movie',
       'Hidden Gem Score', 'Country Availability', 'Runtime', 'View Rating',
       'IMDb Score', 'Rotten Tomatoes Score', 'Metacritic Score',
       'Awards Received', 'Awards Nominated For', 'Boxoffice', 'Release Date',
       'Netflix Release Date', 'IMDb Votes']]
explode_Country.set_index(['Title', 'Genre', 'Tags', 'Languages', 'Series or Movie',
       'Hidden Gem Score', 'Runtime', 'View Rating',
       'IMDb Score', 'Rotten Tomatoes Score', 'Metacritic Score',
       'Awards Received', 'Awards Nominated For', 'Boxoffice', 'Release Date',
       'Netflix Release Date', 'IMDb Votes'],inplace=True)
explode_Country = explode_Country.apply(lambda x: x.str.split(',').explode().str.strip())
explode_Country.reset_index(inplace=True)
explode_Country.head()
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2     The Con-Heartist                         Comedy, Romance
# 3         Gleboka woda                                   Drama
# 4        Only a Mother                                   Drama
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2  Romantic Comedies,Comedies,Romantic Films,Thai...              Thai
# 3   TV Dramas,Polish TV Shows,Social Issue TV Dramas            Polish
# 4  Social Issue Dramas,Dramas,Movies Based on Boo...           Swedish
#
#   Series or Movie  Hidden Gem Score       Runtime View Rating  IMDb Score  \
# 0          Series               4.3  < 30 minutes           R         7.9
# 1           Movie               7.0      1-2 hour           R         5.8
# 2           Movie               8.6       > 2 hrs         NaN         7.4
# 3          Series               8.7  < 30 minutes         NaN         7.5
# 4           Movie               8.3      1-2 hour         NaN         6.7
#
#    Rotten Tomatoes Score  Metacritic Score  Awards Received  \
# 0                   98.0              82.0             74.0
# 1                   79.0              69.0              1.0
# 2                    NaN               NaN              NaN
# 3                    NaN               NaN              2.0
# 4                    NaN               NaN              2.0
#
#    Awards Nominated For   Boxoffice Release Date Netflix Release Date  \
# 0                  57.0  $2,122,065  12 Dec 2008           2021-03-04
# 1                   NaN     $70,632  08 May 2020           2021-03-04
# 2                   NaN         NaN  03 Dec 2020           2021-03-03
# 3                   4.0         NaN  14 Jun 2011           2021-03-03
# 4                   1.0         NaN  31 Oct 1949           2021-03-03
#
#    IMDb Votes Country Availability
# 0    205926.0             Thailand
# 1      2838.0               Canada
# 2       131.0             Thailand
# 3        47.0               Poland
# 4        88.0            Lithuania

# %%
# code to separate Languages column into individual rows
explode_Lang = cleaned_df[['Title', 'Genre', 'Tags', 'Languages', 'Series or Movie',
       'Hidden Gem Score', 'Country Availability', 'Runtime', 'View Rating',
       'IMDb Score', 'Rotten Tomatoes Score', 'Metacritic Score',
       'Awards Received', 'Awards Nominated For', 'Boxoffice', 'Release Date',
       'Netflix Release Date', 'IMDb Votes']]
explode_Lang.set_index(['Title', 'Genre', 'Tags', 'Series or Movie',
       'Hidden Gem Score', 'Country Availability', 'Runtime', 'View Rating',
       'IMDb Score', 'Rotten Tomatoes Score', 'Metacritic Score',
       'Awards Received', 'Awards Nominated For', 'Boxoffice', 'Release Date',
       'Netflix Release Date', 'IMDb Votes'],inplace=True)
explode_Lang = explode_Lang.apply(lambda x: x.str.split(',').explode().str.strip())
explode_Lang.reset_index(inplace=True)
explode_Lang.head()
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 2  HOW TO BUILD A GIRL                                  Comedy
# 3     The Con-Heartist                         Comedy, Romance
# 4         Gleboka woda                                   Drama
#
#                                                 Tags Series or Movie  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...          Series
# 1  Comedy Programmes,Romantic TV Comedies,Horror ...          Series
# 2       Dramas,Comedies,Films Based on Books,British           Movie
# 3  Romantic Comedies,Comedies,Romantic Films,Thai...           Movie
# 4   TV Dramas,Polish TV Shows,Social Issue TV Dramas          Series
#
#    Hidden Gem Score Country Availability       Runtime View Rating  \
# 0               4.3             Thailand  < 30 minutes           R
# 1               4.3             Thailand  < 30 minutes           R
# 2               7.0               Canada      1-2 hour           R
# 3               8.6             Thailand       > 2 hrs         NaN
# 4               8.7               Poland  < 30 minutes         NaN
#
#    IMDb Score  Rotten Tomatoes Score  Metacritic Score  Awards Received  \
# 0         7.9                   98.0              82.0             74.0
# 1         7.9                   98.0              82.0             74.0
# 2         5.8                   79.0              69.0              1.0
# 3         7.4                    NaN               NaN              NaN
# 4         7.5                    NaN               NaN              2.0
#
#    Awards Nominated For   Boxoffice Release Date Netflix Release Date  \
# 0                  57.0  $2,122,065  12 Dec 2008           2021-03-04
# 1                  57.0  $2,122,065  12 Dec 2008           2021-03-04
# 2                   NaN     $70,632  08 May 2020           2021-03-04
# 3                   NaN         NaN  03 Dec 2020           2021-03-03
# 4                   4.0         NaN  14 Jun 2011           2021-03-03
#
#    IMDb Votes Languages
# 0    205926.0   Swedish
# 1    205926.0   Spanish
# 2      2838.0   English
# 3       131.0      Thai
# 4        47.0    Polish

# %%
# code to separate genre into individual rows
explode_genre = cleaned_df[['Title', 'Genre', 'Tags', 'Languages', 'Series or Movie',
       'Hidden Gem Score', 'Country Availability', 'Runtime', 'View Rating',
       'IMDb Score', 'Rotten Tomatoes Score', 'Metacritic Score',
       'Awards Received', 'Awards Nominated For', 'Boxoffice', 'Release Date',
       'Netflix Release Date', 'IMDb Votes']]
explode_genre.set_index(['Title', 'Tags', 'Languages', 'Series or Movie',
       'Hidden Gem Score', 'Country Availability', 'Runtime', 'View Rating',
       'IMDb Score', 'Rotten Tomatoes Score', 'Metacritic Score',
       'Awards Received', 'Awards Nominated For', 'Boxoffice', 'Release Date',
       'Netflix Release Date', 'IMDb Votes'],inplace=True)
explode_genre = explode_genre.apply(lambda x: x.str.split(',').explode().str.strip())
explode_genre.reset_index(inplace=True)
explode_genre.head()
# Out:
#               Title                                               Tags  \
# 0  Lets Fight Ghost  Comedy Programmes,Romantic TV Comedies,Horror ...
# 1  Lets Fight Ghost  Comedy Programmes,Romantic TV Comedies,Horror ...
# 2  Lets Fight Ghost  Comedy Programmes,Romantic TV Comedies,Horror ...
# 3  Lets Fight Ghost  Comedy Programmes,Romantic TV Comedies,Horror ...
# 4  Lets Fight Ghost  Comedy Programmes,Romantic TV Comedies,Horror ...
#
#           Languages Series or Movie  Hidden Gem Score Country Availability  \
# 0  Swedish, Spanish          Series               4.3             Thailand
# 1  Swedish, Spanish          Series               4.3             Thailand
# 2  Swedish, Spanish          Series               4.3             Thailand
# 3  Swedish, Spanish          Series               4.3             Thailand
# 4  Swedish, Spanish          Series               4.3             Thailand
#
#         Runtime View Rating  IMDb Score  Rotten Tomatoes Score  \
# 0  < 30 minutes           R         7.9                   98.0
# 1  < 30 minutes           R         7.9                   98.0
# 2  < 30 minutes           R         7.9                   98.0
# 3  < 30 minutes           R         7.9                   98.0
# 4  < 30 minutes           R         7.9                   98.0
#
#    Metacritic Score  Awards Received  Awards Nominated For   Boxoffice  \
# 0              82.0             74.0                  57.0  $2,122,065
# 1              82.0             74.0                  57.0  $2,122,065
# 2              82.0             74.0                  57.0  $2,122,065
# 3              82.0             74.0                  57.0  $2,122,065
# 4              82.0             74.0                  57.0  $2,122,065
#
#   Release Date Netflix Release Date  IMDb Votes    Genre
# 0  12 Dec 2008           2021-03-04    205926.0    Crime
# 1  12 Dec 2008           2021-03-04    205926.0    Drama
# 2  12 Dec 2008           2021-03-04    205926.0  Fantasy
# 3  12 Dec 2008           2021-03-04    205926.0   Horror
# 4  12 Dec 2008           2021-03-04    205926.0  Romance

# %%
# Export to csv files
# explode_Country.to_csv(r"Resources/netflix_country.csv")
# explode_Lang.to_csv(r"Resources/netflix_language.csv")
# explode_genre.to_csv(r"Resources/netflix_genre.csv")
